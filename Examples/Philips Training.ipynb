# %% [markdown]
# # Learnging Pandas

# %% [markdown]
# ## Jupyter basics
# * Print python command outputs
# * importing a csv file
# ---

# %%
import pandas as pd

# %%
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit: None
#
# pandas: 0.22.0
# pytest: 3.3.2
# pip: 9.0.1
# setuptools: 38.4.0
# Cython: 0.27.3
# numpy: 1.14.0
# scipy: 1.0.0
# pyarrow: None
# xarray: None
# IPython: 6.2.1
# sphinx: 1.6.6
# patsy: 0.5.0
# dateutil: 2.6.1
# pytz: 2017.3
# blosc: None
# bottleneck: 1.2.1
# tables: 3.4.2
# numexpr: 2.6.4
# feather: None
# matplotlib: 2.1.2
# openpyxl: 2.4.10
# xlrd: 1.1.0
# xlwt: 1.2.0
# xlsxwriter: 1.0.2
# lxml: 4.1.1
# bs4: 4.6.0
# html5lib: 1.0.1
# sqlalchemy: 1.2.1
# pymysql: 0.8.0
# psycopg2: 2.7.4 (dt dec pq3 ext lo64)
# jinja2: 2.10
# s3fs: None
# fastparquet: None
# pandas_gbq: None
# pandas_datareader: None

# %%
pd.__version__
# Out:
# '0.22.0'

# %%
pd.read_csv?

# %%
data = pd.read_csv('olympics.csv', skiprows=4)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data
# Out:
#           City  Edition      Sport       Discipline  \
# 0       Athens     1896   Aquatics         Swimming
# 1       Athens     1896   Aquatics         Swimming
# 2       Athens     1896   Aquatics         Swimming
# 3       Athens     1896   Aquatics         Swimming
# 4       Athens     1896   Aquatics         Swimming
# 5       Athens     1896   Aquatics         Swimming
# 6       Athens     1896   Aquatics         Swimming
# 7       Athens     1896   Aquatics         Swimming
# 8       Athens     1896   Aquatics         Swimming
# 9       Athens     1896   Aquatics         Swimming
# 10      Athens     1896   Aquatics         Swimming
# 11      Athens     1896  Athletics        Athletics
# 12      Athens     1896  Athletics        Athletics
# 13      Athens     1896  Athletics        Athletics
# 14      Athens     1896  Athletics        Athletics
# 15      Athens     1896  Athletics        Athletics
# 16      Athens     1896  Athletics        Athletics
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 10 columns):
# City            29216 non-null object
# Edition         29216 non-null int64
# Sport           29216 non-null object
# Discipline      29216 non-null object
# Athlete         29216 non-null object
# NOC             29216 non-null object
# Gender          29216 non-null object
# Event           29216 non-null object
# Event_gender    29216 non-null object
# Medal           29216 non-null object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ MB

# %%
data.size
# Out:
# 292160

# %%
data.head(3)
# Out:
#      City  Edition     Sport Discipline            Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming      HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming   HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming  DRIVAS, Dimitrios  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze

# %%
data.tail()
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender       Event Event_gender   Medal
# 29211  GER    Men   84 - 96kg            M  Silver
# 29212  LTU    Men  96 - 120kg            M  Bronze
# 29213  ARM    Men  96 - 120kg            M  Bronze
# 29214  CUB    Men  96 - 120kg            M    Gold
# 29215  RUS    Men  96 - 120kg            M  Silver

# %%
type(data['City'])
# Out:
# pandas.core.series.Series

# %%
 data.City
# Out:
# 0         Athens
# 1         Athens
# 2         Athens
# 3         Athens
# 4         Athens
# 5         Athens
# 6         Athens
# 7         Athens
# 8         Athens
# 9         Athens
# 10        Athens
# 11        Athens
# 12        Athens
# 13        Athens
# 14        Athens
# 15        Athens
# 16        Athens
# 17        Athens
# 18        Athens
# 19        Athens
# 20        Athens
# 21        Athens
# 22        Athens
# 23        Athens
# 24        Athens
# 25        Athens
# 26        Athens
# 27        Athens
# 28        Athens
# 29        Athens
#           ...
# 29186    Beijing
# 29187    Beijing
# 29188    Beijing
# 29189    Beijing
# 29190    Beijing
# 29191    Beijing
# 29192    Beijing
# 29193    Beijing
# 29194    Beijing
# 29195    Beijing
# 29196    Beijing
# 29197    Beijing
# 29198    Beijing
# 29199    Beijing
# 29200    Beijing
# 29201    Beijing
# 29202    Beijing
# 29203    Beijing
# 29204    Beijing
# 29205    Beijing
# 29206    Beijing
# ...

# %%
data[['City', 'Athlete']]
# Out:
#           City                      Athlete
# 0       Athens                HAJOS, Alfred
# 1       Athens             HERSCHMANN, Otto
# 2       Athens            DRIVAS, Dimitrios
# 3       Athens           MALOKINIS, Ioannis
# 4       Athens           CHASAPIS, Spiridon
# 5       Athens        CHOROPHAS, Efstathios
# 6       Athens                HAJOS, Alfred
# 7       Athens             ANDREOU, Joannis
# 8       Athens        CHOROPHAS, Efstathios
# 9       Athens                NEUMANN, Paul
# 10      Athens            PEPANOS, Antonios
# 11      Athens                LANE, Francis
# 12      Athens             SZOKOLYI, Alajos
# 13      Athens                BURKE, Thomas
# 14      Athens               HOFMANN, Fritz
# 15      Athens               CURTIS, Thomas
# 16      Athens           GOULDING, Grantley
# 17      Athens            LERMUSIAUX, Albin
# 18      Athens                 FLACK, Edwin
# 19      Athens                BLAKE, Arthur
# ...

# %%
data.City=='Athens'
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# 5         True
# 6         True
# 7         True
# 8         True
# 9         True
# 10        True
# 11        True
# 12        True
# 13        True
# 14        True
# 15        True
# 16        True
# 17        True
# 18        True
# 19        True
# 20        True
# 21        True
# 22        True
# 23        True
# 24        True
# 25        True
# 26        True
# 27        True
# 28        True
# 29        True
#          ...
# 29186    False
# 29187    False
# 29188    False
# 29189    False
# 29190    False
# 29191    False
# 29192    False
# 29193    False
# 29194    False
# 29195    False
# 29196    False
# 29197    False
# 29198    False
# 29199    False
# 29200    False
# 29201    False
# 29202    False
# 29203    False
# 29204    False
# 29205    False
# 29206    False
# 29207    False
# 29208    False
# 29209    False
# 29210    False
# 29211    False
# 29212    False
# ...

# %%
data.City.value_counts()
# Out:
# Athens                   2149
# Los Angeles              2074
# Beijing                  2042
# Sydney                   2015
# Atlanta                  1859
# Barcelona                1705
# London                   1618
# Seoul                    1546
# Paris                    1396
# Moscow                   1387
# Montreal                 1305
# Antwerp                  1298
# Munich                   1185
# Mexico                   1031
# Tokyo                    1010
# Helsinki                  889
# Melbourne / Stockholm     885
# Stockholm                 885
# Rome                      882
# Berlin                    875
# Amsterdam                 710
# St Louis                  470
# Name: City, dtype: int64

# %%
data.Edition.value_counts()
# Out:
# 2008    2042
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1031
# 1964    1010
# 1952     889
# 1912     885
# 1956     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: Edition, dtype: int64

# %% [markdown]
# ### The 'shape' attribute of the DataFrame returns the dimension (rows, cols)

# %%
data[data.Gender=='Women'].shape
# Out:
# (7495, 10)

# %%
data[data.Gender=='Women'][['Athlete', 'City', 'Medal']]
# Out:
#                                  Athlete      City   Medal
# 416                         PRATT, Daria     Paris  Bronze
# 417                ABBOTT, Margaret Ives     Paris    Gold
# 418                    WHITTIER, Pauline     Paris  Silver
# 639                        JONES, Marion     Paris  Bronze
# 640                    ROSENBAUM, Hedwig     Paris  Bronze
# 641                    COOPER, Charlotte     Paris    Gold
# 642                      PREVOST, Hélène     Paris  Silver
# 647                        JONES, Marion     Paris  Bronze
# 648                    ROSENBAUM, Hedwig     Paris  Bronze
# 649                    COOPER, Charlotte     Paris    Gold
# 650                      PREVOST, Hélène     Paris  Silver
# 709                      POLLOCK, Jessie  St Louis  Bronze
# 710                HOWELL, Matilda Scott  St Louis    Gold
# 711                       COOKE, Emma C.  St Louis  Silver
# 712                      POLLOCK, Jessie  St Louis  Bronze
# ...

# %%
data.Athlete.sort_values(ascending=False)
# Out:
# 8051              ÖSTRAND, Per-Olof
# 596                      ÖSTMO, Ole
# 621                      ÖSTMO, Ole
# 608                      ÖSTMO, Ole
# 603                      ÖSTMO, Ole
# 3740           ÖSTERVOLD, Ole Olsen
# 3739      ÖSTERVOLD, Kristian Olsen
# 3738           ÖSTERVOLD, Jan Olsen
# 3737              ÖSTERVOLD, Henrik
# 3942                ÖSTENSEN, Östen
# 2730                ÖSTENSEN, Östen
# 3870                ÖSTENSEN, Östen
# 4009                ÖSTENSEN, Östen
# 3868                ÖSTENSEN, Östen
# 3747                    ÖRVIG, Thor
# 3746                    ÖRVIG, Olav
# 3745                    ÖRVIG, Erik
# 2691                ÖRTEGREN, Ruben
# 15711           ÖRSTED, Hans-Henrik
# 1939                 ZÜRNER, Albert
# 1138                 ZÜRNER, Albert
# 18534                ZÜLOW, Andreas
# 19282               ZÜHLKE, Steffen
# 10596              ZÄHRINGER, Klaus
# 25639                ZYKINA, Olesya
# 23611                ZYKINA, Olesya
# ...

# %%
data[(data.Gender=='Women') & (data.Medal=='Gold')]
# Out:
#             City  Edition          Sport       Discipline  \
# 417        Paris     1900           Golf             Golf
# 641        Paris     1900         Tennis           Tennis
# 649        Paris     1900         Tennis           Tennis
# 710     St Louis     1904        Archery          Archery
# 713     St Louis     1904        Archery          Archery
# 730     St Louis     1904        Archery          Archery
# 731     St Louis     1904        Archery          Archery
# 732     St Louis     1904        Archery          Archery
# 733     St Louis     1904        Archery          Archery
# 1185      London     1908        Archery          Archery
# 1843      London     1908        Skating   Figure skating
# 1849      London     1908        Skating   Figure skating
# 1870      London     1908         Tennis           Tennis
# 1876      London     1908         Tennis           Tennis
# 1941   Stockholm     1912       Aquatics           Diving
# ...

# %%
data.sort_values(['City', 'Athlete'], ascending=False)
# Out:
#             City  Edition          Sport       Discipline  \
# 10948      Tokyo     1964      Athletics        Athletics
# 11207      Tokyo     1964        Fencing          Fencing
# 10917      Tokyo     1964      Athletics        Athletics
# 11079      Tokyo     1964        Cycling     Cycling Road
# 11443      Tokyo     1964         Rowing           Rowing
# 11054      Tokyo     1964  Canoe / Kayak  Canoe / Kayak F
# 11624      Tokyo     1964  Weightlifting    Weightlifting
# 10866      Tokyo     1964      Athletics        Athletics
# 11180      Tokyo     1964        Fencing          Fencing
# 11619      Tokyo     1964  Weightlifting    Weightlifting
# 11628      Tokyo     1964  Weightlifting    Weightlifting
# 11070      Tokyo     1964        Cycling     Cycling Road
# 11046      Tokyo     1964  Canoe / Kayak  Canoe / Kayak F
# 11068      Tokyo     1964  Canoe / Kayak  Canoe / Kayak F
# 11385      Tokyo     1964         Hockey           Hockey
# ...

# %% [markdown]
# ### Using MatPlotLib to plot a chart

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data.City.value_counts().plot(kind='barh', figsize=(10, 6), color='#0000FF')

# %%
data.City.value_counts().plot()

# %%
import seaborn as sns

# %%
data.Sport.value_counts().plot(kind='pie')

# %%
sns.countplot(data=data, x='Medal');

# %%
sns.countplot(data=data, x='Gender', palette='bwr');

# %%
type(data.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
data.set_index('City', inplace=True)

# %%
data.head()
# Out:
#         Edition     Sport Discipline             Athlete  NOC Gender  \
# City
# Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                              Event Event_gender   Medal
# City
# Athens              100m freestyle            M    Gold
# Athens              100m freestyle            M  Silver
# Athens  100m freestyle for sailors            M  Bronze
# Athens  100m freestyle for sailors            M    Gold
# Athens  100m freestyle for sailors            M  Silver

# %%
data[data.index=='Tokyo']
# Out:
#        Edition      Sport       Discipline                      Athlete  NOC  \
# City
# Tokyo     1964   Aquatics           Diving          GOMPF, Thomas Eugen  USA
# Tokyo     1964   Aquatics           Diving        WEBSTER, Robert David  USA
# Tokyo     1964   Aquatics           Diving               DIBIASI, Klaus  ITA
# Tokyo     1964   Aquatics           Diving            ALEKSEEVA, Galina  URS
# Tokyo     1964   Aquatics           Diving           BUSH, Lesley Leigh  USA
# Tokyo     1964   Aquatics           Diving  KRÄMER-ENGEL-GULBIN, Ingrid  EUA
# Tokyo     1964   Aquatics           Diving    ANDREASEN, Lawrence Edwin  USA
# Tokyo     1964   Aquatics           Diving   SITZBERGER, Kenneth Robert  USA
# Tokyo     1964   Aquatics           Diving       GORMAN, Francis Xavier  USA
# Tokyo     1964   Aquatics           Diving       WILLARD, Mary Patricia  USA
# Tokyo     1964   Aquatics           Diving  KRÄMER-ENGEL-GULBIN, Ingrid  EUA
# ...

# %%
data.reset_index()
# Out:
#           City  Edition      Sport       Discipline  \
# 0       Athens     1896   Aquatics         Swimming
# 1       Athens     1896   Aquatics         Swimming
# 2       Athens     1896   Aquatics         Swimming
# 3       Athens     1896   Aquatics         Swimming
# 4       Athens     1896   Aquatics         Swimming
# 5       Athens     1896   Aquatics         Swimming
# 6       Athens     1896   Aquatics         Swimming
# 7       Athens     1896   Aquatics         Swimming
# 8       Athens     1896   Aquatics         Swimming
# 9       Athens     1896   Aquatics         Swimming
# 10      Athens     1896   Aquatics         Swimming
# 11      Athens     1896  Athletics        Athletics
# 12      Athens     1896  Athletics        Athletics
# 13      Athens     1896  Athletics        Athletics
# 14      Athens     1896  Athletics        Athletics
# 15      Athens     1896  Athletics        Athletics
# 16      Athens     1896  Athletics        Athletics
# ...

# %%
type(data.Athlete)
# Out:
# pandas.core.series.Series

# %%
data[data.Athlete=='BOLT, Usain']
# Out:
#          Edition      Sport Discipline      Athlete  NOC Gender         Event  \
# City
# Beijing     2008  Athletics  Athletics  BOLT, Usain  JAM    Men          100m
# Beijing     2008  Athletics  Athletics  BOLT, Usain  JAM    Men          200m
# Beijing     2008  Athletics  Athletics  BOLT, Usain  JAM    Men  4x100m relay
#
#         Event_gender Medal
# City
# Beijing            M  Gold
# Beijing            M  Gold
# Beijing            M  Gold

# %%
data[data.Athlete.str.contains('Singh')]
# Out:
#              Edition   Sport Discipline               Athlete  NOC Gender  \
# City
# Los Angeles     1932  Hockey     Hockey      BAIS, Roop Singh  IND    Men
# Berlin          1936  Hockey     Hockey      BAIS, Roop Singh  IND    Men
# Moscow          1980  Hockey     Hockey   AMARJIT RANA, Singh  IND    Men
# Moscow          1980  Hockey     Hockey      DEAVINDER, Singh  IND    Men
# Moscow          1980  Hockey     Hockey        GURMAIL, Singh  IND    Men
# Moscow          1980  Hockey     Hockey          SINGH, Singh  IND    Men
# Moscow          1980  Hockey     Hockey          SINGH, Singh  IND    Men
# Moscow          1980  Hockey     Hockey       SURINDER, Singh  IND    Men
# Los Angeles     1984  Hockey     Hockey  BHAURA, Kulbir Singh  GBR    Men
# Seoul           1988  Hockey     Hockey  BHAURA, Kulbir Singh  GBR    Men
#
#               Event Event_gender   Medal
# City
# Los Angeles  hockey            M    Gold
# Berlin       hockey            M    Gold
# ...

# %% [markdown]
# # End of Pandas basic training
